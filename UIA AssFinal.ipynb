# %% [markdown]
# ###### while True:
#     print "\nWelcome to the AGoS System of UIA"
#     option = raw_input('Please Select an Option\n<A>add details of a student.\n'
#     '<S>search student details for a student.\n<Q>quit.\n')
#     if option.lower() == 'a':
#         f=open('uia.txt','a')
#         details=[]
#         columns = ['Id\t','S.Name\t','A.AssigM1\t','A.AssigM2\t','W.AssigM1\t','W.AssigM2\t','T.W.AssignM\t',
#                    'W.M.Final\t','SubTotal\t','B.Mar\t','FinTotM\n']
#         f.writelines(columns)
#         p_id = raw_input('Please enter the student ID :')
#         p_name = raw_input('Please enter the student name:')
#         p_ass1 = raw_input('Please enter the marks for Assignment 1:')
#         p_ass2 = raw_input('Please enter the marks for Assignment 2:')
#         p_finm = raw_input('Please enter the marks for the Final Exam:')
#         print "Thank you !"
#         if  p_finm <= '80':
#             p_was1 = '16'
#             p_was2 = '27'
#         else:
#             p_was1 = 20
#             p_was2 = 30
#         p_twm = str(int(p_was1)+int(p_was2))
#         p_wms = str(int(p_finm)/int(2))
#         p_subwt = str(int(p_twm)+int(p_wms))
#         p_details = [p_id, p_name,p_mar,p_ass1,p_ass2,p_finm,p_was1,p_was2,p_twm,p_wms,p_subwt]
#         f.writelines(p_details)
#         print p_details
#         f.close()

# %%
while True:
    print "\nWelcome to the AGoS System of UIA"
    option = raw_input('Please Select an Option\n<A>add details of a student.\n'
    '<S>search student details for a student.\n<Q>quit.\n')
    if option.lower() == 'a':
        f=open('uia.txt','w')
        details=[]
        columns = ['Id\t','S.Name\t','A.AssigM1\t','A.AssigM2\t','W.AssigM1\t','W.AssigM2\t','T.W.AssignM\t',
                   'W.M.Final\t','SubTotal\t','B.Mar\t','FinTotM\n']
        f.writelines(columns)
        p_id = raw_input('Please enter the student ID :')
        p_name = raw_input('Please enter the student name:')
        p_ass1 = raw_input('Please enter the marks for Assignment 1:')
        p_ass2 = raw_input('Please enter the marks for Assignment 2:')
        p_finm = raw_input('Please enter the marks for the Final Exam:')
        print "Thank you !"
        if  p_finm <= '80':
            p_was1 = '16'
            p_was2 = '27'
        else:
            p_was1 = '20'
            p_was2 = '30'
        p_twm = str(int(p_was1)+int(p_was2))
        p_wms = str(int(p_finm)/int(2))
        p_subwt = str(int(p_twm)+int(p_wms))
        p_details = [p_id+\t, p_name+\t,p_ass1+\t,p_ass2+\t,p_finm+\t,p_was1+\t,p_was2+\t,p_twm+\t,p_wms+\t,p_subwt+\t]
        f.writelines(p_details)
        print p_details
        f.close()
# Out:
# Welcome to the AGoS System of UIA
# Please Select an Option
# <A>add details of a student.
# <S>search student details for a student.
# <Q>quit.
# a
# Please enter the student ID :100
# Please enter the student name:sharath
# Please enter the marks for Assignment 1:80
# Please enter the marks for Assignment 2:90
# Please enter the marks for the Final Exam:85
# Thank you !
# ['100', 'sharath', '80', '90', '85', '20', '30', '50', '42', '92']
#
# Welcome to the AGoS System of UIA

# %%
while True:
    print "\nWelcome to the AGoS System of UIA"
    option = raw_input('Please Select an Option\n<A>add details of a student.\n'
    '<S>search student details for a student.\n<Q>quit.\n')
    if option.lower() == 'a':
        f=open('uia.txt','w')
        details=[]
        columns = ['Id\t','S.Name\t','A.AssigM1\t','A.AssigM2\t','W.AssigM1\t','W.AssigM2\t','T.W.AssignM\t',
                   'W.M.Final\t','SubTotal\t','FinTotM\n']
        f.writelines(columns)
        p_id = raw_input('Please enter the student ID :')
        p_name = raw_input('Please enter the student name:')
        p_ass1 = raw_input('Please enter the marks for Assignment 1:')
        p_ass2 = raw_input('Please enter the marks for Assignment 2:')
        p_finm = raw_input('Please enter the marks for the Final Exam:')
        print "Thank you !"
        if  p_finm <= '80':
            p_was1 = '16'
            p_was2 = '27'
        else:
            p_was1 = '20'
            p_was2 = '30'
        p_twm = str(int(p_was1)+int(p_was2))
        p_wms = str(int(p_finm)/int(2))
        p_subwt = str(int(p_twm)+int(p_wms))
        p_details = [p_id+'\t', p_name+'\t',p_ass1+'\t',p_ass2+'\t',p_finm+'\t',p_was1+'\t',p_was2+'\t',p_twm+'\t',p_wms+'\t',p_subwt+'\n']
        f.writelines(p_details)
        print p_details
        f.close()
# Out:
# Welcome to the AGoS System of UIA
# Please Select an Option
# <A>add details of a student.
# <S>search student details for a student.
# <Q>quit.
# a
# Please enter the student ID :101
# Please enter the student name:sharath
# Please enter the marks for Assignment 1:90
# Please enter the marks for Assignment 2:90
# Please enter the marks for the Final Exam:90
# Thank you !
# ['101\t', 'sharath\t', '90\t', '90\t', '90\t', '20\t', '30\t', '50\t', '45\t', '95\n']
#
# Welcome to the AGoS System of UIA

# %%
while True:
    print "\nWelcome to the AGoS System of UIA"
    option = raw_input('Please Select an Option\n<A>add details of a student.\n'
    '<S>search student details for a student.\n<Q>quit.\n')
    if option.lower() == 'a':
        f=open('uia.txt','w')
        details=[]
        columns = ['Id\t','S.Name\t','A.AssigM1\t','A.AssigM2\t','W.AssigM1\t','W.AssigM2\t','T.W.AssignM\t',
                   'W.M.Final\t','SubTotal\t','FinTotM\n']
        f.writelines(columns)
        p_id = raw_input('Please enter the student ID :')
        p_name = raw_input('Please enter the student name:')
        p_ass1 = raw_input('Please enter the marks for Assignment 1:')
        p_ass2 = raw_input('Please enter the marks for Assignment 2:')
        p_finm = raw_input('Please enter the marks for the Final Exam:')
        print "Thank you !"
        if  p_finm <= '80':
            p_was1 = '16'
            p_was2 = '27'
        else:
            p_was1 = '20'
            p_was2 = '30'
        p_twm = str(int(p_was1)+int(p_was2))
        p_wms = str(int(p_finm)/int(2))
        p_subwt = str(int(p_twm)+int(p_wms))
        p_details = [p_id+'\t', p_name+'\t',p_ass1+'\t',p_ass2+'\t',p_finm+'\t',p_was1+'\t',p_was2+'\t',p_twm+'\t',p_wms+'\t',p_subwt+'\n']
        f.writelines(p_details)
        print p_details
        f.close()
# Out:
# Welcome to the AGoS System of UIA
# Please Select an Option
# <A>add details of a student.
# <S>search student details for a student.
# <Q>quit.
# a
# Please enter the student ID :101
# Please enter the student name:sharath
# Please enter the marks for Assignment 1:90
# Please enter the marks for Assignment 2:80
# Please enter the marks for the Final Exam:40
# Thank you !
# ['101\t', 'sharath\t', '90\t', '80\t', '40\t', '16\t', '27\t', '43\t', '20\t', '63\n']
#
# Welcome to the AGoS System of UIA

# %%
while True:
    print "\nWelcome to the AGoS System of UIA"
    option = raw_input('Please Select an Option\n<A>add details of a student.\n'
    '<S>search student details for a student.\n<Q>quit.\n')
    if option.lower() == 'a':
        f=open('uia.txt','w')
        details=[]
        columns = ['Id\t','S.Name\t','A.AssigM1\t','A.AssigM2\t','W.AssigM1\t','W.AssigM2\t','T.W.AssignM\t',
                   'W.M.Final\t','SubTotal\t','FinTotM\n']
        f.writelines(columns)
        p_id = raw_input('Please enter the student ID :')
        p_name = raw_input('Please enter the student name:')
        p_ass1 = raw_input('Please enter the marks for Assignment 1:')
        p_ass2 = raw_input('Please enter the marks for Assignment 2:')
        p_finm = raw_input('Please enter the marks for the Final Exam:')
        print "Thank you !"
        if  p_finm <= '80':
            p_was1 = '16'
            p_was2 = '27'
        else:
            p_was1 = '20'
            p_was2 = '30'
        p_twm = str(int(p_was1)+int(p_was2))
        p_wms = str(int(p_finm)/int(2))
        p_subwt = str(int(p_twm)+int(p_wms))
        p_details = [p_id+'\t', p_name+'\t',p_ass1+'\t',p_ass2+'\t',p_finm+'\t',p_was1+'\t',p_was2+'\t',p_twm+'\t',p_wms+'\t',p_subwt+'\n']
        f.writelines(p_details)
        print columns
        print p_details
        f.close()
    elif option.lower() == 's':
        f = open("uia.txt",'r')
        search = raw_input('Please Enter the Student Id to Search: ')
        data = f.readlines()
        print columns.split('\t')
        for p_details in data:
            if p_details.split('\t')[0] == search:
                print p_details
        else :
            print 'Entered id details are not found'
# Out:
# Welcome to the AGoS System of UIA
# Please Select an Option
# <A>add details of a student.
# <S>search student details for a student.
# <Q>quit.
# s
# Please Enter the Student Id to Search: 101
# ['Id\tS.Name\tA.AssigM1\tA.AssigM2\tW.AssigM1\tW.AssigM2\tT.W.AssignM\tW.M.Final\tSubTotal\tFinTotM\n', '102\thyderabad\t65\t39\t78\t16\t27\t43\t39\t82\n']
# Entered id details are not found
#
# Welcome to the AGoS System of UIA

# %%
columns = ['Id\t','S.Name\t','A.AssigM1\t','A.AssigM2\t','W.AssigM1\t','W.AssigM2\t','T.W.AssignM\t',
                   'W.M.Final\t','SubTotal\t','FinTotM\n']
while True:
    print "\nWelcome to the AGoS System of UIA"
    option = raw_input('Please Select an Option\n<A>add details of a student.\n'
    '<S>search student details for a student.\n<Q>quit.\n')
    if option.lower() == 'a':
        f=open('uia.txt','w')
        details=[]
        f.writelines(columns)
        p_id = raw_input('Please enter the student ID :')
        p_name = raw_input('Please enter the student name:')
        p_ass1 = raw_input('Please enter the marks for Assignment 1:')
        p_ass2 = raw_input('Please enter the marks for Assignment 2:')
        p_finm = raw_input('Please enter the marks for the Final Exam:')
        print "Thank you !"
        if  p_finm <= '80':
            p_was1 = '16'
            p_was2 = '27'
        else:
            p_was1 = '20'
            p_was2 = '30'
        p_twm = str(int(p_was1)+int(p_was2))
        p_wms = str(int(p_finm)/int(2))
        p_subwt = str(int(p_twm)+int(p_wms))
        p_details = [p_id+'\t', p_name+'\t',p_ass1+'\t',p_ass2+'\t',p_finm+'\t',p_was1+'\t',p_was2+'\t',p_twm+'\t',p_wms+'\t',p_subwt+'\n']
        f.writelines(p_details)
        print columns
        print p_details
        f.close()
    elif option.lower() == 's':
        f = open("uia.txt",'r')
        search = raw_input('Please Enter the Student Id to Search: ')
        data = f.readlines()
        print columns.split('\t')
        for p_details in data:
            if p_details.split('\t')[0] == search:
                print p_details
        else :
            print 'Entered id details are not found'
# Out:
# Welcome to the AGoS System of UIA
# Please Select an Option
# <A>add details of a student.
# <S>search student details for a student.
# <Q>quit.
# s
# Please Enter the Student Id to Search: 102
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a1fcb6d1efb1> in <module>()
#      33         search = raw_input('Please Enter the Student Id to Search: ')
#      34         data = f.readlines()
# ---> 35         print columns.split('\t')
#      36         for p_details in data:
#      37             if p_details.split('\t')[0] == search:
#
# NameError: name 'columns' is not defined

# %%
while True:
    print "\nWelcome to the AGoS System of UIA"
    option = raw_input('Please Select an Option\n<A>add details of a student.\n'
    '<S>search student details for a student.\n<Q>quit.\n')
    if option.lower() == 'a':
        f=open('uia.txt','w')
        columns = ['Id\t','S.Name\t','A.AssigM1\t','A.AssigM2\t','W.AssigM1\t','W.AssigM2\t','T.W.AssignM\t',
                   'W.M.Final\t','SubTotal\t','FinTotM\n']
        f.writelines(columns)
        p_id = raw_input('Please enter the student ID :')
        p_name = raw_input('Please enter the student name:')
        p_ass1 = raw_input('Please enter the marks for Assignment 1:')
        p_ass2 = raw_input('Please enter the marks for Assignment 2:')
        p_finm = raw_input('Please enter the marks for the Final Exam:')
        print "Thank you !"
        if  p_finm <= '80':
            p_was1 = '16'
            p_was2 = '27'
        else:
            p_was1 = '20'
            p_was2 = '30'
        p_twm = str(int(p_was1)+int(p_was2))
        p_wms = str(int(p_finm)/int(2))
        p_subwt = str(int(p_twm)+int(p_wms))
        p_details = [p_id+'\t', p_name+'\t',p_ass1+'\t',p_ass2+'\t',p_finm+'\t',p_was1+'\t',p_was2+'\t',p_twm+'\t',p_wms+'\t',p_subwt+'\n']
        f.writelines(p_details)
        print columns
        print p_details
        f.close()
    elif option.lower() == 's':
        f = open("uia.txt",'r')
        search = raw_input('Please Enter the Student Id to Search: ')
        data = f.readlines()
        for p_details in data:
            if p_details.split('\t')[0] == search:
                print p_details
        else :
            print 'Entered id details are not found'

# %%
while True:
    print "\nWelcome to the AGoS System of UIA"
    option = raw_input('Please Select an Option\n<A>add details of a student.\n'
    '<S>search student details for a student.\n<Q>quit.\n')
    if option.lower() == 'a':
        f=open('uia.txt','w')
        columns = ['Id\t','S.Name\t','A.AssigM1\t','A.AssigM2\t','W.AssigM1\t','W.AssigM2\t','T.W.AssignM\t',
                   'W.M.Final\t','SubTotal\t','FinTotM\n']
        f.writelines(columns)
        p_id = raw_input('Please enter the student ID :')
        p_name = raw_input('Please enter the student name:')
        p_ass1 = raw_input('Please enter the marks for Assignment 1:')
        p_ass2 = raw_input('Please enter the marks for Assignment 2:')
        p_finm = raw_input('Please enter the marks for the Final Exam:')
        print "Thank you !"
        if  p_finm <= '80':
            p_was1 = '16'
            p_was2 = '27'
        else:
            p_was1 = '20'
            p_was2 = '30'
        p_twm = str(int(p_was1)+int(p_was2))
        p_wms = str(int(p_finm)/int(2))
        p_subwt = str(int(p_twm)+int(p_wms))
        p_details = [p_id+'\t', p_name+'\t',p_ass1+'\t',p_ass2+'\t',p_finm+'\t',p_was1+'\t',p_was2+'\t',p_twm+'\t',p_wms+'\t',p_subwt+'\n']
        f.writelines(p_details)
        print columns
        print p_details
        f.close()
    elif option.lower() == 's':
        f = open("uia.txt",'r')
        search = raw_input('Please Enter the Student Id to Search: ')
        data = f.readlines()
        for rows in data:
            if row.split('\t')[0] == search:
                print p_details
        else :
            print 'Entered id details are not found'
# Out:
# Welcome to the AGoS System of UIA
# Please Select an Option
# <A>add details of a student.
# <S>search student details for a student.
# <Q>quit.
# s
# Please Enter the Student Id to Search: 102
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2013675c9ffb> in <module>()
#      33         data = f.readlines()
#      34         for rows in data:
# ---> 35             if row.split('\t')[0] == search:
#      36                 print p_details
#      37         else :
#
# NameError: name 'row' is not defined

# %%
while True:
    print "\nWelcome to the AGoS System of UIA"
    option = raw_input('Please Select an Option\n<A>add details of a student.\n'
    '<S>search student details for a student.\n<Q>quit.\n')
    if option.lower() == 'a':
        f=open('uia.txt','w')
        columns = ['Id\t','S.Name\t','A.AssigM1\t','A.AssigM2\t','W.AssigM1\t','W.AssigM2\t','T.W.AssignM\t',
                   'W.M.Final\t','SubTotal\t','FinTotM\n']
        f.writelines(columns)
        p_id = raw_input('Please enter the student ID :')
        p_name = raw_input('Please enter the student name:')
        p_ass1 = raw_input('Please enter the marks for Assignment 1:')
        p_ass2 = raw_input('Please enter the marks for Assignment 2:')
        p_finm = raw_input('Please enter the marks for the Final Exam:')
        print "Thank you !"
        if  p_finm <= '80':
            p_was1 = '16'
            p_was2 = '27'
        else:
            p_was1 = '20'
            p_was2 = '30'
        p_twm = str(int(p_was1)+int(p_was2))
        p_wms = str(int(p_finm)/int(2))
        p_subwt = str(int(p_twm)+int(p_wms))
        p_details = [p_id+'\t', p_name+'\t',p_ass1+'\t',p_ass2+'\t',p_finm+'\t',p_was1+'\t',p_was2+'\t',p_twm+'\t',p_wms+'\t',p_subwt+'\n']
        f.writelines(p_details)
        print columns
        print p_details
        f.close()
    elif option.lower() == 's':
        f = open("uia.txt",'r')
        search = raw_input('Please Enter the Student Id to Search: ')
        data = f.readlines()
        for p_details in data:
            if p_details.split('\t')[0] == search:
                print p_details
            #elif p_details.split('\t')[0] != search: 
               # print 'Entered id details are not found'
    elif option.lower() == 'q':
        print "Exiting the application"
        break
# Out:
# Welcome to the AGoS System of UIA
# Please Select an Option
# <A>add details of a student.
# <S>search student details for a student.
# <Q>quit.
# q
# Exiting the application

# %%
while True:
    print "\nWelcome to the AGoS System of UIA"
    option = raw_input('Please Select an Option\n<A>add details of a student.\n'
    '<S>search student details for a student.\n<Q>quit.\n')
    if option.lower() == 'a':
        f=open('uia.txt','w')
        columns = ['Id\t','S.Name\t','A.AssigM1\t','A.AssigM2\t','W.AssigM1\t','W.AssigM2\t','T.W.AssignM\t',
                   'W.M.Final\t','SubTotal\t','FinTotM\n']
        f.writelines(columns)
        p_id = raw_input('Please enter the student ID :')
        p_name = raw_input('Please enter the student name:')
        p_ass1 = raw_input('Please enter the marks for Assignment 1:')
        p_ass2 = raw_input('Please enter the marks for Assignment 2:')
        p_finm = raw_input('Please enter the marks for the Final Exam:')
        print "Thank you !"
        if  p_finm <= '80':
            p_was1 = '16'
            p_was2 = '27'
        else:
            p_was1 = '20'
            p_was2 = '30'
        p_twm = str(int(p_was1)+int(p_was2))
        p_wms = str(int(p_finm)/int(2))
        p_subwt = str(int(p_twm)+int(p_wms))
        p_details = [p_id+'\t', p_name+'\t',p_ass1+'\t',p_ass2+'\t',p_finm+'\t',p_was1+'\t',p_was2+'\t',p_twm+'\t',p_wms+'\t',p_subwt+'\n']
        f.writelines(p_details)
        print columns
        print p_details
        f.close()
    elif option.lower() == 's':
        f = open("uia.txt",'r')
        search = raw_input('Please Enter the Student Id to Search: ')
        data = f.readlines()
        for p_details in data:
            if p_details.split('\t')[0] == search:
                print p_details
            #elif p_details.split('\t')[0] != search: 
               # print 'Entered id details are not found'
    elif option.lower() == 'q':
        print "Exiting the application"
        break
# Out:
# Welcome to the AGoS System of UIA
# Please Select an Option
# <A>add details of a student.
# <S>search student details for a student.
# <Q>quit.
# s
# Please Enter the Student Id to Search: 105
# 105	Shatrath	65	39	78	16	27	43	39	82
#
#
# Welcome to the AGoS System of UIA
# Please Select an Option
# <A>add details of a student.
# <S>search student details for a student.
# <Q>quit.
# q
# Exiting the application

# %%
columns = ['Id\t','S.Name\t','A.AssigM1\t','A.AssigM2\t','W.AssigM1\t','W.AssigM2\t','T.W.AssignM\t',
                   'W.M.Final\t','SubTotal\t','FinTotM\n']
while True:
    print "\nWelcome to the AGoS System of UIA"
    option = raw_input('Please Select an Option\n<A>add details of a student.\n'
    '<S>search student details for a student.\n<Q>quit.\n')
    if option.lower() == 'a':
        f=open('uia.txt','w')
        details=[]
        f.writelines(columns)
        p_id = raw_input('Please enter the student ID :')
        p_name = raw_input('Please enter the student name:')
        p_ass1 = raw_input('Please enter the marks for Assignment 1:')
        p_ass2 = raw_input('Please enter the marks for Assignment 2:')
        p_finm = raw_input('Please enter the marks for the Final Exam:')
        print "Thank you !"
        if  p_finm <= '80':
            p_was1 = '16'
            p_was2 = '27'
        else:
            p_was1 = '20'
            p_was2 = '30'
        p_twm = str(int(p_was1)+int(p_was2))
        p_wms = str(int(p_finm)/int(2))
        p_subwt = str(int(p_twm)+int(p_wms))
        p_details = [p_id+'\t', p_name+'\t',p_ass1+'\t',p_ass2+'\t',p_finm+'\t',p_was1+'\t',p_was2+'\t',p_twm+'\t',p_wms+'\t',p_subwt+'\n']
        f.writelines(p_details)
        print columns
        print p_details
        f.close()
    elif option.lower() == 's':
        f = open("uia.txt",'r')
        search = raw_input('Please Enter the Student Id to Search: ')
        data = f.readlines()
        print columns.split('\t')
        for p_details in data:
            if p_details.split('\t')[0] == search:
                print p_details
        else :
            print 'Entered id details are not found'
# Out:
# Welcome to the AGoS System of UIA
# Please Select an Option
# <A>add details of a student.
# <S>search student details for a student.
# <Q>quit.
# a
# Please enter the student ID :109
# Please enter the student name:Sharath
# Please enter the marks for Assignment 1:98
# Please enter the marks for Assignment 2:84
# Please enter the marks for the Final Exam:65
# Thank you !
# ['Id\t', 'S.Name\t', 'A.AssigM1\t', 'A.AssigM2\t', 'W.AssigM1\t', 'W.AssigM2\t', 'T.W.AssignM\t', 'W.M.Final\t', 'SubTotal\t', 'FinTotM\n']
# ['109\t', 'Sharath\t', '98\t', '84\t', '65\t', '16\t', '27\t', '43\t', '32\t', '75\n']
#
# Welcome to the AGoS System of UIA
# Please Select an Option
# <A>add details of a student.
# <S>search student details for a student.
# <Q>quit.
# q
#
# Welcome to the AGoS System of UIA

# %%
studentList = []
f=open('IUA.txt','w')
column = ['StudentId\t','StudentName\t','A1\t','A2\t','FinalExam\t','WeightedTotal\t','WeightedTotalwithBonus']
f.writelines(column)
f.close()
def inputValues():

    while True:
        print ("-----------------------------------------------------------------------------------------")         #print header
        print ("The Innovation University of Australia (IUA) Grade System ")
        print ("-----------------------------------------------------------------------------------------")

        print ("Please enter all marks out of 100")                                 #print message
        studentID = input("Please enter the student ID: ")
        studentName = input("Please enter the student name: ")
        assign1 = int(input("Please enter the marks for Assignment 1: "))           #input marks for assignment1
        assign2 = int(input("Please enter the marks for Assignment 2 : "))           #input marks for assignment2
        finalExam = int(input("Please enter the marks for Final Exam: "))         #input marks for final exam

        print ("Thank You!")   
                                                             #print thank you
        student = [studentID, studentName, assign1, assign2, finalExam]
        total_weight, total_weight_bonus = calculate(student)
        student.append(total_weight)
        student.append(total_weight_bonus)
        #studentList.append(student)
        f=open('IUA.txt','a')
        row=[str(value).center(len(column))+"\t" for value,column in zip(student,column)]
        row[0] = "\n"+row[0]
        f.writelines(row)
        f.close()
        ans = input("Do you want to enter marks for another student (Y/N)?")

        if ans != 'Y':
            return

def calculate(student):
    weight1 = int(student[2]) * 0.2                                                     #calculate weight for assignment1
    weight2 = int(student[3]) * 0.3                                                     #calculate weight for assignment2
    assignWeight = weight1 + weight2                                            #calculate total weight for assignments

    print ("Weighted mark for Assignment 1: ", weight1)                         #print weight of assignment1
    print ("Weighted mark for Assignment 2: ", weight2)                         #print weight of assignment2
    print ("Weighted mark for Assignment 1: ", assignWeight)                    #print total weight for assignments

    finalWeight = int(student[4]) * 0.5                                               #calculate weight for final exam
    totalWeight = assignWeight + finalWeight                                    #calculate total weight
            
    print ("Weighted mark for the Final Exam is: ", finalWeight)                #print weight of final exam
    print ("Total weighted mark for the subject: ", totalWeight)                #print total weight

    if totalWeight < 50:                                                        #check totalWeight and assign bonus
        bonus = 0 
    elif totalWeight < 70:
        bonus = (totalWeight-50) * 0.1
    elif totalWeight < 90:
        bonus = 2 + (totalWeight-70) * 0.15
    else:
        bonus = 5 + (totalWeight-90) * 0.2

    print ("Bonus mark: ", bonus)                                               #print bonus
    total = totalWeight + bonus                                                 #calculate total marks
    print ("Total mark with bonus: ", total) 
                                   #print total marks
    return  totalWeight, total

def searchStudent():

    while True:
        print ("-----------------------------------------------------------------------------------------")         #print header
        print ("The Innovation University of Australia (IUA) Grade System ")
        print ("-----------------------------------------------------------------------------------------")
        ID = input("Please enter the student ID to search: ")

        with open('IUA.txt', 'r') as f:
            studentList = [line.split('\t') for line in f.readlines()]

        flag = 0
        for student in studentList:
            if student[0].strip() == str(ID):
                print ("".join(column))
                print ("___"*30)
                print ("".join(student))
                flag = 1
                break

        if flag == 0:
            print ("Student Not Found")

        ans = input("Do you want to search for another student (Y/N)?")

        if ans != 'Y':
            return


while True:
    print ("================================================ ")
    print ("Welcome to the AGoS System of IUA")
    print ("Please select an option from the following.")
    print ("<A>dd details of a student")
    print ("<S>earch details of a student.")
    print ("<Q>uit")
    print ("================================================ ")
    option = input("Enter the option:")
    if option == 'A':
            inputValues()
    elif option == 'S':
            searchStudent()
    elif option == 'Q':
            break;
    else:
            print ("Incorrect option!! Please try again")
# Out:
# ...
# Welcome to the AGoS System of IUA
# Please select an option from the following.
# <A>dd details of a student
# <S>earch details of a student.
# <Q>uit
# ...
# Enter the option:a
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-74b1e6f6256c> in <module>()
#     102     print ("<Q>uit")
#     103     print ("================================================ ")
# --> 104     option = input("Enter the option:")
#     105     if option == 'A':
#     106             inputValues()
#
# C:\Users\ASPIRE\Anaconda2\lib\site-packages\ipykernel\ipkernel.pyc in <lambda>(prompt)
#     162             self._sys_eval_input = builtin_mod.input
#     163             builtin_mod.raw_input = self.raw_input
# --> 164             builtin_mod.input = lambda prompt='': eval(self.raw_input(prompt))
#     165         self._save_getpass = getpass.getpass
# ...

# %%
studentList = []
f=open('IUA.txt','w')
column = ['StudentId\t','StudentName\t','A1\t','A2\t','FinalExam\t','WeightedTotal\t','WeightedTotalwithBonus']
f.writelines(column)
f.close()
def inputValues():

    while True:
        print ("-----------------------------------------------------------------------------------------")         #print header
        print ("The Innovation University of Australia (IUA) Grade System ")
        print ("-----------------------------------------------------------------------------------------")

        print ("Please enter all marks out of 100")                                 #print message
        studentID = input("Please enter the student ID: ")
        studentName = input("Please enter the student name: ")
        assign1 = int(input("Please enter the marks for Assignment 1: "))           #input marks for assignment1
        assign2 = int(input("Please enter the marks for Assignment 2 : "))           #input marks for assignment2
        finalExam = int(input("Please enter the marks for Final Exam: "))         #input marks for final exam

        print ("Thank You!")   
                                                             #print thank you
        student = [studentID, studentName, assign1, assign2, finalExam]
        total_weight, total_weight_bonus = calculate(student)
        student.append(total_weight)
        student.append(total_weight_bonus)
        #studentList.append(student)
        f=open('IUA.txt','a')
        row=[str(value).center(len(column))+"\t" for value,column in zip(student,column)]
        row[0] = "\n"+row[0]
        f.writelines(row)
        f.close()
        ans = input("Do you want to enter marks for another student (Y/N)?")

        if ans != 'Y':
            return

def calculate(student):
    weight1 = int(student[2]) * 0.2                                                     #calculate weight for assignment1
    weight2 = int(student[3]) * 0.3                                                     #calculate weight for assignment2
    assignWeight = weight1 + weight2                                            #calculate total weight for assignments

    print ("Weighted mark for Assignment 1: ", weight1)                         #print weight of assignment1
    print ("Weighted mark for Assignment 2: ", weight2)                         #print weight of assignment2
    print ("Weighted mark for Assignment 1: ", assignWeight)                    #print total weight for assignments

    finalWeight = int(student[4]) * 0.5                                               #calculate weight for final exam
    totalWeight = assignWeight + finalWeight                                    #calculate total weight
            
    print ("Weighted mark for the Final Exam is: ", finalWeight)                #print weight of final exam
    print ("Total weighted mark for the subject: ", totalWeight)                #print total weight

    if totalWeight < 50:                                                        #check totalWeight and assign bonus
        bonus = 0 
    elif totalWeight < 70:
        bonus = (totalWeight-50) * 0.1
    elif totalWeight < 90:
        bonus = 2 + (totalWeight-70) * 0.15
    else:
        bonus = 5 + (totalWeight-90) * 0.2

    print ("Bonus mark: ", bonus)                                               #print bonus
    total = totalWeight + bonus                                                 #calculate total marks
    print ("Total mark with bonus: ", total) 
                                   #print total marks
    return  totalWeight, total

def searchStudent():

    while True:
        print ("-----------------------------------------------------------------------------------------")         #print header
        print ("The Innovation University of Australia (IUA) Grade System ")
        print ("-----------------------------------------------------------------------------------------")
        ID = input("Please enter the student ID to search: ")

        with open('IUA.txt', 'r') as f:
            studentList = [line.split('\t') for line in f.readlines()]

        flag = 0
        for student in studentList:
            if student[0].strip() == str(ID):
                print ("".join(column))
                print ("___"*30)
                print ("".join(student))
                flag = 1
                break

        if flag == 0:
            print ("Student Not Found")

        ans = input("Do you want to search for another student (Y/N)?")

        if ans != 'Y':
            return


while True:
    print ("================================================ ")
    print ("Welcome to the AGoS System of IUA")
    print ("Please select an option from the following.")
    print ("<A>dd details of a student")
    print ("<S>earch details of a student.")
    print ("<Q>uit")
    print ("================================================ ")
    option = input("Enter the option:")
    if option.islower() == 'A':
            inputValues()
    elif option == 'S':
            searchStudent()
    elif option.islower() == 'Q':
            break;
    else:
            print ("Incorrect option!! Please try again")
# Out:
# ...
# Welcome to the AGoS System of IUA
# Please select an option from the following.
# <A>dd details of a student
# <S>earch details of a student.
# <Q>uit
# ...
# Enter the option:a
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2d93feaea373> in <module>()
#     102     print ("<Q>uit")
#     103     print ("================================================ ")
# --> 104     option = input("Enter the option:")
#     105     if option.islower() == 'A':
#     106             inputValues()
#
# C:\Users\ASPIRE\Anaconda2\lib\site-packages\ipykernel\ipkernel.pyc in <lambda>(prompt)
#     162             self._sys_eval_input = builtin_mod.input
#     163             builtin_mod.raw_input = self.raw_input
# --> 164             builtin_mod.input = lambda prompt='': eval(self.raw_input(prompt))
#     165         self._save_getpass = getpass.getpass
# ...

# %%
studentList = []
f=open('IUA.txt','w')
column = ['StudentId\t','StudentName\t','A1\t','A2\t','FinalExam\t','WeightedTotal\t','WeightedTotalwithBonus']
f.writelines(column)
f.close()
def inputValues():

    while True:
        print ("-----------------------------------------------------------------------------------------")         #print header
        print ("The Innovation University of Australia (IUA) Grade System ")
        print ("-----------------------------------------------------------------------------------------")

        print ("Please enter all marks out of 100")                                 #print message
        studentID = input("Please enter the student ID: ")
        studentName = input("Please enter the student name: ")
        assign1 = int(input("Please enter the marks for Assignment 1: "))           #input marks for assignment1
        assign2 = int(input("Please enter the marks for Assignment 2 : "))           #input marks for assignment2
        finalExam = int(input("Please enter the marks for Final Exam: "))         #input marks for final exam

        print ("Thank You!")   
                                                             #print thank you
        student = [studentID, studentName, assign1, assign2, finalExam]
        total_weight, total_weight_bonus = calculate(student)
        student.append(total_weight)
        student.append(total_weight_bonus)
        #studentList.append(student)
        f=open('IUA.txt','a')
        row=[str(value).center(len(column))+"\t" for value,column in zip(student,column)]
        row[0] = "\n"+row[0]
        f.writelines(row)
        f.close()
        ans = input("Do you want to enter marks for another student (Y/N)?")

        if ans != 'Y':
            return

def calculate(student):
    weight1 = int(student[2]) * 0.2                                                     #calculate weight for assignment1
    weight2 = int(student[3]) * 0.3                                                     #calculate weight for assignment2
    assignWeight = weight1 + weight2                                            #calculate total weight for assignments

    print ("Weighted mark for Assignment 1: ", weight1)                         #print weight of assignment1
    print ("Weighted mark for Assignment 2: ", weight2)                         #print weight of assignment2
    print ("Weighted mark for Assignment 1: ", assignWeight)                    #print total weight for assignments

    finalWeight = int(student[4]) * 0.5                                               #calculate weight for final exam
    totalWeight = assignWeight + finalWeight                                    #calculate total weight
            
    print ("Weighted mark for the Final Exam is: ", finalWeight)                #print weight of final exam
    print ("Total weighted mark for the subject: ", totalWeight)                #print total weight

    if totalWeight < 50:                                                        #check totalWeight and assign bonus
        bonus = 0 
    elif totalWeight < 70:
        bonus = (totalWeight-50) * 0.1
    elif totalWeight < 90:
        bonus = 2 + (totalWeight-70) * 0.15
    else:
        bonus = 5 + (totalWeight-90) * 0.2

    print ("Bonus mark: ", bonus)                                               #print bonus
    total = totalWeight + bonus                                                 #calculate total marks
    print ("Total mark with bonus: ", total) 
                                   #print total marks
    return  totalWeight, total

def searchStudent():

    while True:
        print ("-----------------------------------------------------------------------------------------")         #print header
        print ("The Innovation University of Australia (IUA) Grade System ")
        print ("-----------------------------------------------------------------------------------------")
        ID = input("Please enter the student ID to search: ")

        with open('IUA.txt', 'r') as f:
            studentList = [line.split('\t') for line in f.readlines()]

        flag = 0
        for student in studentList:
            if student[0].strip() == str(ID):
                print ("".join(column))
                print ("___"*30)
                print ("".join(student))
                flag = 1
                break

        if flag == 0:
            print ("Student Not Found")

        ans = input("Do you want to search for another student (Y/N)?")

        if ans != 'Y':
            return


while True:
    print ("================================================ ")
    print ("Welcome to the AGoS System of IUA")
    print ("Please select an option from the following.")
    print ("<A>dd details of a student")
    print ("<S>earch details of a student.")
    print ("<Q>uit")
    print ("================================================ ")
    option = input("Enter the option:")
    if option.lower() == 'A':
            inputValues()
    elif option == 'S':
            searchStudent()
    elif option.lower() == 'Q':
            break;
    else:
            print ("Incorrect option!! Please try again")
# Out:
# ...
# Welcome to the AGoS System of IUA
# Please select an option from the following.
# <A>dd details of a student
# <S>earch details of a student.
# <Q>uit
# ...
# Enter the option:a
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bffe8ccdae0b> in <module>()
#     102     print ("<Q>uit")
#     103     print ("================================================ ")
# --> 104     option = input("Enter the option:")
#     105     if option.lower() == 'A':
#     106             inputValues()
#
# C:\Users\ASPIRE\Anaconda2\lib\site-packages\ipykernel\ipkernel.pyc in <lambda>(prompt)
#     162             self._sys_eval_input = builtin_mod.input
#     163             builtin_mod.raw_input = self.raw_input
# --> 164             builtin_mod.input = lambda prompt='': eval(self.raw_input(prompt))
#     165         self._save_getpass = getpass.getpass
# ...

# %%
studentList = []
f=open('IUA.txt','w')
column = ['StudentId\t','StudentName\t','A1\t','A2\t','FinalExam\t','WeightedTotal\t','WeightedTotalwithBonus']
f.writelines(column)
f.close()
def inputValues():

    while True:
        print ("-----------------------------------------------------------------------------------------")         #print header
        print ("The Innovation University of Australia (IUA) Grade System ")
        print ("-----------------------------------------------------------------------------------------")

        print ("Please enter all marks out of 100")                                 #print message
        studentID = input("Please enter the student ID: ")
        studentName = input("Please enter the student name: ")
        assign1 = int(input("Please enter the marks for Assignment 1: "))           #input marks for assignment1
        assign2 = int(input("Please enter the marks for Assignment 2 : "))           #input marks for assignment2
        finalExam = int(input("Please enter the marks for Final Exam: "))         #input marks for final exam

        print ("Thank You!")   
                                                             #print thank you
        student = [studentID, studentName, assign1, assign2, finalExam]
        total_weight, total_weight_bonus = calculate(student)
        student.append(total_weight)
        student.append(total_weight_bonus)
        #studentList.append(student)
        f=open('IUA.txt','a')
        row=[str(value).center(len(column))+"\t" for value,column in zip(student,column)]
        row[0] = "\n"+row[0]
        f.writelines(row)
        f.close()
        ans = input("Do you want to enter marks for another student (Y/N)?")

        if ans != 'Y':
            return

def calculate(student):
    weight1 = int(student[2]) * 0.2                                                     #calculate weight for assignment1
    weight2 = int(student[3]) * 0.3                                                     #calculate weight for assignment2
    assignWeight = weight1 + weight2                                            #calculate total weight for assignments

    print ("Weighted mark for Assignment 1: ", weight1)                         #print weight of assignment1
    print ("Weighted mark for Assignment 2: ", weight2)                         #print weight of assignment2
    print ("Weighted mark for Assignment 1: ", assignWeight)                    #print total weight for assignments

    finalWeight = int(student[4]) * 0.5                                               #calculate weight for final exam
    totalWeight = assignWeight + finalWeight                                    #calculate total weight
            
    print ("Weighted mark for the Final Exam is: ", finalWeight)                #print weight of final exam
    print ("Total weighted mark for the subject: ", totalWeight)                #print total weight

    if totalWeight < 50:                                                        #check totalWeight and assign bonus
        bonus = 0 
    elif totalWeight < 70:
        bonus = (totalWeight-50) * 0.1
    elif totalWeight < 90:
        bonus = 2 + (totalWeight-70) * 0.15
    else:
        bonus = 5 + (totalWeight-90) * 0.2

    print ("Bonus mark: ", bonus)                                               #print bonus
    total = totalWeight + bonus                                                 #calculate total marks
    print ("Total mark with bonus: ", total) 
                                   #print total marks
    return  totalWeight, total

def searchStudent():

    while True:
        print ("-----------------------------------------------------------------------------------------")         #print header
        print ("The Innovation University of Australia (IUA) Grade System ")
        print ("-----------------------------------------------------------------------------------------")
        ID = input("Please enter the student ID to search: ")

        with open('IUA.txt', 'r') as f:
            studentList = [line.split('\t') for line in f.readlines()]

        flag = 0
        for student in studentList:
            if student[0].strip() == str(ID):
                print ("".join(column))
                print ("___"*30)
                print ("".join(student))
                flag = 1
                break

        if flag == 0:
            print ("Student Not Found")

        ans = input("Do you want to search for another student (Y/N)?")

        if ans != 'Y':
            return


while True:
    print ("================================================ ")
    print ("Welcome to the AGoS System of IUA")
    print ("Please select an option from the following.")
    print ("<A>dd details of a student")
    print ("<S>earch details of a student.")
    print ("<Q>uit")
    print ("================================================ ")
    option = input("Enter the option:")
    if option.islower() == 'A':
            inputValues()
    elif option == 'S':
            searchStudent()
    elif option.islower() == 'Q':
            break;
    else:
            print ("Incorrect option!! Please try again")
# Out:
# ...
# Welcome to the AGoS System of IUA
# Please select an option from the following.
# <A>dd details of a student
# <S>earch details of a student.
# <Q>uit
# ...
# Enter the option:A
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2d93feaea373> in <module>()
#     102     print ("<Q>uit")
#     103     print ("================================================ ")
# --> 104     option = input("Enter the option:")
#     105     if option.islower() == 'A':
#     106             inputValues()
#
# C:\Users\ASPIRE\Anaconda2\lib\site-packages\ipykernel\ipkernel.pyc in <lambda>(prompt)
#     162             self._sys_eval_input = builtin_mod.input
#     163             builtin_mod.raw_input = self.raw_input
# --> 164             builtin_mod.input = lambda prompt='': eval(self.raw_input(prompt))
#     165         self._save_getpass = getpass.getpass
# ...
