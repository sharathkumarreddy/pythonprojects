# %%
num = 7
if num > 3:
    print("3")
    if num < 5:
        print("5")
        if num == 7:
            print("7")
# Out:
# 3

# %%
x=4
y=2
if not 1 + 1 == y or x == 4 and 7 == 8:
    print("yes")
elif x>y:
    print("no")
# Out:
# no

# %%
x=5
x
# Out:
# 5

# %%
i = 3
while i>=0:
    print(i)
    i = i -1
# Out:
# 3
# 2
# 1
# 0

# %%
x = "vamsi"
y = "10"
z = x+y
print(z)
# Out:
# vamsi10

# %%
print("in the loop")
# Out:
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# in the loop
# ...
